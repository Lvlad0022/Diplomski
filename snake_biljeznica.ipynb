# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
import random
random.randint(0,1)
# Out:
# 0

# %%
df1 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\snake__polyakTrue_gamma0.99_doubleqTrue_priorityTrue_noisynetTrue_no_survive_reward_2025-12-02_12-22-22")

df2 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\snake__polyakTrue_gamma0.99_doubleqTrue_priorityTrue_noisynetTrue_no_survive_reward_2025-12-01_14-33-12")

# %%
df1.columns
# Out:
# Index(['game', 'avg_count', 'avg_reward', 'avg_jabuka', 'vrijeme'], dtype='object')

# %%
(df1["avg_count"]).plot()
(df2["avg_count"]).plot()
# Out:
# <Axes: >

# %%
(df1["avg_jabuka"]).plot()
(df2["avg_jabuka"]).plot()
# Out:
# <Axes: >

# %%
df1 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\Diplomski\level2\classicSnake\log\pretrain_model_2025-12-04_12-50-32.csv")

# %%
np.log(df1["avg_loss"]).plot()
# Out:
# <Axes: >

# %%
np.random.choice(3, size=1, replace=False)
# Out:
# array([2])

# %%
y = np.random.choice(visits1, size = 50000)

# %%
u,val = np.unique(y,return_counts = True)

# %%
visits1, err1 = visits1[err1 < 100]  ,err1[err1 < 100]

# %%
i = np.argsort(err1)[::-1]
err1[i]
# Out:
# array([99.0590727 , 97.20941655, 97.12947875, ...,  0.        ,
#         0.        ,  0.        ])

# %%
from scipy.stats import pearsonr

corr, p = pearsonr(visits1, err1)
print(corr, p)
# Out:
# -0.1440534088956262 0.0

# %%
index = np.random.choice(np.arange(start = 0, stop = visits1.shape[0]), size = 1000)
y = err1[index]
x = visits1[index]

plt.scatter(x,y)

# %%
plt.hist(visits2, bins=100)   # number of bins is adjustable
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()
