# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
import random
random.randint(0,1)
# Out:
# 0

# %%
df1 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\acrobot__polyakTrue_gamma0.99_doubleqFalse_priorityFalse_2025-11-29_04-48-38")
df2 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\acrobot__polyakTrue_gamma0.99_doubleqFalse_priorityTrue_2025-11-29_06-35-27")
df3 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\acrobot__polyakTrue_gamma0.99_doubleqTrue_priorityFalse_2025-11-28_23-40-15")
df4 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\acrobot__polyakTrue_gamma0.99_doubleqTrue_priorityTrue_2025-11-29_01-38-26")

# %%
(df1["avg_count"]).plot()
(df2["avg_count"]).plot()
(df3["avg_count"]).plot()
(df4["avg_count"]).plot()
# Out:
# <Axes: >

# %%
(df4["vrijeme"]).plot()
(df3["vrijeme"]).plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 (df4["vrijeme"]).plot()
# ----> 2 (df3["vrijeme"]).plot()
#
# File c:\Users\lovro\miniconda3\envs\torch\lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\lovro\miniconda3\envs\torch\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
y = np.random.choice(visits1, size = 50000)

# %%
u,val = np.unique(y,return_counts = True)

# %%
visits1, err1 = visits1[err1 < 100]  ,err1[err1 < 100]

# %%
i = np.argsort(err1)[::-1]
err1[i]
# Out:
# array([99.0590727 , 97.20941655, 97.12947875, ...,  0.        ,
#         0.        ,  0.        ])

# %%
from scipy.stats import pearsonr

corr, p = pearsonr(visits1, err1)
print(corr, p)
# Out:
# -0.1440534088956262 0.0

# %%
index = np.random.choice(np.arange(start = 0, stop = visits1.shape[0]), size = 1000)
y = err1[index]
x = visits1[index]

plt.scatter(x,y)

# %%
plt.hist(visits2, bins=100)   # number of bins is adjustable
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()
