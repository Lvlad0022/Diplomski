# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
df1 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\simple_snake_game_models\zsave_simple_snake3_log_n3_nondueling_memory0_scheduler1_gamma0.85_2025-11-23_09-48-18.csv")
df2 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\simple_snake_game_models\zsave_simple_snake3_log_n3_dueling_memory1_scheduler1_gamma0.85_2025-11-26_00-06-51.csv")
df3 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\simple_snake_game_models\zsave_simple_snake3_log_n3_dueling_memory1_scheduler1_gamma0.85_2025-11-26_18-14-24.csv")
df4 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\simple_snake_game_models\zsave_simple_snake3_log_n3_dueling_memory1_scheduler1_gamma0.85_2025-11-26_19-14-53.csv")

# %%
np.log(df1["loss_moving_avg"]).plot()
np.log(df2["loss_moving_avg"]).plot()
np.log(df3["loss_moving_avg"]).plot()
np.log(df4["loss_moving_avg"]).plot()
# Out:
# c:\Users\lovro\miniconda3\envs\torch\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\lovro\miniconda3\envs\torch\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\lovro\miniconda3\envs\torch\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\lovro\miniconda3\envs\torch\lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <Axes: >

# %%
df3["learning_rate"].plot()
# Out:
# <Axes: >

# %%
#(df1["avg_count"]).plot()
(df2["avg_count"]).plot()
(df4["avg_count"]).plot()
# Out:
# <Axes: >

# %%
(df3["win_pct"]).plot()
(df2["win_pct"]).plot()
# Out:
# <Axes: >

# %%
err1 = np.load(r"C:\Users\lovro\Desktop\diplomski za stare brancheve\save_simple_snake_log_n3_dueling_memory6_scheduler4_gamma0.85_2025-11-20_05-12-46_visits.npy")
visits1 = np.load(r"C:\Users\lovro\Desktop\diplomski za stare brancheve\save_simple_snake_log_n3_dueling_memory6_scheduler4_gamma0.85_2025-11-20_05-12-46_errors.npy")
visits2 = np.load(r"C:\Users\lovro\Desktop\diplomski za stare brancheve\save_simple_snake_log_n3_dueling_memory6_scheduler3_gamma0.85_2025-11-19_18-17-04_errors.npy")
err2 = np.load(r"C:\Users\lovro\Desktop\diplomski za stare brancheve\save_simple_snake_log_n3_dueling_memory6_scheduler3_gamma0.85_2025-11-19_18-17-04_visits.npy")

# %%
y = np.random.choice(visits1, size = 50000)

# %%
u,val = np.unique(y,return_counts = True)

# %%
visits1, err1 = visits1[err1 < 100]  ,err1[err1 < 100]

# %%
i = np.argsort(err1)[::-1]
err1[i]
# Out:
# array([99.0590727 , 97.20941655, 97.12947875, ...,  0.        ,
#         0.        ,  0.        ])

# %%
from scipy.stats import pearsonr

corr, p = pearsonr(visits1, err1)
print(corr, p)
# Out:
# -0.1440534088956262 0.0

# %%
index = np.random.choice(np.arange(start = 0, stop = visits1.shape[0]), size = 1000)
y = err1[index]
x = visits1[index]

plt.scatter(x,y)

# %%
plt.hist(visits2, bins=100)   # number of bins is adjustable
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()
