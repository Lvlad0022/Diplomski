# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
import random
random.randint(0,1)
# Out:
# 0

# %%
df1 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\snakeagent1__polyakTrue_gamma0.99_doubleqTrue_priorityTrue_noisynetTruezero_survive_reward_2025-12-05_17-13-00")
df2 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\snakeagent1__polyakTrue_gamma0.99_doubleqTrue_priorityTrue_noisynetTruezero_survive_reward_2025-12-07_15-46-40")
df3 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\snakeagent1__polyakTrue_gamma0.99_doubleqTrue_priorityTrue_noisynetTruezero_survive_reward_2025-12-07_18-30-11")
df4 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\snakeagent1_metadata__polyakTrue_gamma0.99_doubleqTrue_priorityTrue_noisynetTruezero_survive_reward_2025-12-08_16-32-59")

# %%
df1["avg_jabuka"][4000]
# Out:
# 22.471196628843757

# %%
(df1["avg_jabuka"]).plot()
(df2["avg_jabuka"]).plot()
(df3["avg_jabuka"]).plot()
(df4["avg_jabuka"]).plot()
# Out:
# <Axes: >

# %%
(df1["avg_jabuka"]).plot()
(df2["avg_jabuka"]).plot()
# Out:
# <Axes: >

# %%
df1 = pd.read_csv(r"C:\Users\lovro\Desktop\snake\Diplomski\level2\classicSnake\log\pretrain_model_2025-12-04_12-50-32.csv")

# %%
np.log(df1["avg_loss"]).plot()
# Out:
# <Axes: >

# %%
np.random.choice(3, size=1, replace=False)
# Out:
# array([2])

# %%
y = np.random.choice(visits1, size = 50000)

# %%
u,val = np.unique(y,return_counts = True)

# %%
visits1, err1 = visits1[err1 < 100]  ,err1[err1 < 100]

# %%
i = np.argsort(err1)[::-1]
err1[i]
# Out:
# array([99.0590727 , 97.20941655, 97.12947875, ...,  0.        ,
#         0.        ,  0.        ])

# %%
from scipy.stats import pearsonr

corr, p = pearsonr(visits1, err1)
print(corr, p)
# Out:
# -0.1440534088956262 0.0

# %%
index = np.random.choice(np.arange(start = 0, stop = visits1.shape[0]), size = 1000)
y = err1[index]
x = visits1[index]

plt.scatter(x,y)

# %%
plt.hist(visits2, bins=100)   # number of bins is adjustable
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()

# %%
def conv2d_output_size(input_size, kernel_size, stride=1, padding=0, dilation=1):
    
    return (input_size + 2*padding - dilation*(kernel_size - 1) - 1) // stride + 1

def conv2d_output_shape(H_in, W_in, kernel_size, stride=1, padding=0, dilation=1, channels_out=None):
    H_out = conv2d_output_size(H_in, kernel_size, stride, padding, dilation)
    W_out = conv2d_output_size(W_in, kernel_size, stride, padding, dilation)

    if channels_out is None:
        return H_out, W_out
    else:
        return (channels_out, H_out, W_out)

# %%
conv2d_output_shape(10,10,3,1,1)
# Out:
# (10, 10)
